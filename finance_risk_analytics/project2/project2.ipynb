# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import pandas as pd
import seaborn as sns # for making plots with seaborn
color = sns.color_palette()
import sklearn.metrics as metrics
from scipy.stats import norm 
from tabulate import tabulate

from iexfinance.stocks import get_historical_data
from iexfinance.stocks import Stock
from datetime import datetime

import warnings
warnings.filterwarnings("ignore")

# %%
stock_prices = pd.read_csv('Market+Risk+Dataset.csv')

#Glimpse of Data
stock_prices.head(20)
# Out:
#           Date  Infosys  Indian Hotel  Mahindra & Mahindra  Axis Bank  SAIL  \
# 0   31-03-2014      264            69                  455        263    68
# 1   07-04-2014      257            68                  458        276    70
# 2   14-04-2014      254            68                  454        270    68
# 3   21-04-2014      253            68                  488        283    68
# 4   28-04-2014      256            65                  482        282    63
# 5   05-05-2014      248            64                  502        300    67
# 6   12-05-2014      253            68                  508        324    75
# 7   19-05-2014      244            83                  528        344    86
# 8   26-05-2014      234            82                  563        339    84
# 9   02-06-2014      268            89                  561        364   104
# 10  09-06-2014      284            95                  560        335    93
# 11  16-06-2014      296            92                  521        363    90
# 12  23-06-2014      288            94                  525        371    89
# 13  30-06-2014      290            98                  560        376    91
# 14  07-07-2014      297            95                  530        353    78
# 15  14-07-2014      290            86                  539        388    84
# 16  21-07-2014      299            88                  564        386    84
# 17  28-07-2014      298            86                  547        376    82
# 18  04-08-2014      311            79                  573        361    78
# 19  11-08-2014      322            75                  616        367    81
#
#     Shree Cement  Sun Pharma  Jindal Steel  Idea Vodafone  Jet Airways
# 0           5543         555           298             83          278
# 1           5728         610           279             84          303
# 2           5649         607           279             83          280
# 3           5692         604           274             83          282
# 4           5582         611           238             79          243
# 5           5646         606           244             80          239
# 6           6041         596           269             84          244
# 7           6394         567           299             82          289
# 8           6709         593           296             81          241
# 9           7453         582           338             83          259
# 10          7068         611           321             80          250
# 11          7194         613           317             82          242
# 12          7059         641           319             77          253
# 13          7124         689           323             80          274
# 14          7060         722           279             79          246
# 15          7172         721           297             81          254
# 16          6970         759           283             88          251
# 17          7207         746           267             93          247
# 18          7094         738           277             94          244
# 19          7166         791           285             93          236

# %%
stock_prices.columns = stock_prices.columns.str.replace(' ', '_')

# %%
stock_prices.tail()
# Out:
#            Date  Infosys  Indian_Hotel  Mahindra_&_Mahindra  Axis_Bank  SAIL  \
# 309  02-03-2020      729           120                  469        658    33
# 310  09-03-2020      634           114                  427        569    30
# 311  16-03-2020      577            90                  321        428    27
# 312  23-03-2020      644            75                  293        360    21
# 313  30-03-2020      633            75                  284        379    23
#
#      Shree_Cement  Sun_Pharma  Jindal_Steel  Idea_Vodafone  Jet_Airways
# 309         23110         401           146              3           22
# 310         21308         384           121              6           18
# 311         18904         365           105              3           16
# 312         17666         338            89              3           14
# 313         17546         352            82              3           14

# %%
print('The number of rows (observations) is',stock_prices.shape[0],'\n''The number of columns (variables) is',stock_prices.shape[1])
# Out:
# The number of rows (observations) is 314
# The number of columns (variables) is 11

# %%
stock_prices['Date'] = [pd.to_datetime(d) for d in stock_prices['Date']]

# %%
plt.figure(figsize=(10,5))
plt.scatter(stock_prices['Date'], stock_prices['Infosys'], edgecolors='r')
#plt.plot(stock_prices.index, stock_prices['Adj_Close'])
plt.xlabel("Date")
plt.ylabel("$ price")
plt.title("INFOSYS Stock Price 31/3/2014 - 30/3/2020")
# Out:
# Text(0.5, 1.0, 'INFOSYS Stock Price 31/3/2014 - 30/3/2020')

# %%
plt.figure(figsize=(10,5))
plt.scatter(stock_prices['Date'], stock_prices['Mahindra_&_Mahindra'], edgecolors='r')
#plt.plot(stock_prices.index, stock_prices['Adj_Close'])
plt.xlabel("Date")
plt.ylabel("$ price")
plt.title("Mahindra_&_Mahindra Stock Price 31/3/2014 - 30/3/2020")
# Out:
# Text(0.5, 1.0, 'Mahindra_&_Mahindra Stock Price 31/3/2014 - 30/3/2020')

# %%
np.log(stock_prices.drop(['Date'],axis=1)).diff(axis = 0, periods = 1)
# Out:
#       Infosys  Indian_Hotel  Mahindra_&_Mahindra  Axis_Bank      SAIL  \
# 0         NaN           NaN                  NaN        NaN       NaN
# 1   -0.026873     -0.014599             0.006572   0.048247  0.028988
# 2   -0.011742      0.000000            -0.008772  -0.021979 -0.028988
# 3   -0.003945      0.000000             0.072218   0.047025  0.000000
# 4    0.011788     -0.045120            -0.012371  -0.003540 -0.076373
# ..        ...           ...                  ...        ...       ...
# 309  0.009649     -0.110348             0.030305  -0.057580 -0.087011
# 310 -0.139625     -0.051293            -0.093819  -0.145324 -0.095310
# 311 -0.094207     -0.236389            -0.285343  -0.284757 -0.105361
# 312  0.109856     -0.182322            -0.091269  -0.173019 -0.251314
# 313 -0.017228      0.000000            -0.031198   0.051432  0.090972
#
#      Shree_Cement  Sun_Pharma  Jindal_Steel  Idea_Vodafone  Jet_Airways
# 0             NaN         NaN           NaN            NaN          NaN
# 1        0.032831    0.094491     -0.065882       0.011976     0.086112
# 2       -0.013888   -0.004930      0.000000      -0.011976    -0.078943
# 3        0.007583   -0.004955     -0.018084       0.000000     0.007117
# 4       -0.019515    0.011523     -0.140857      -0.049393    -0.148846
# ..            ...         ...           ...            ...          ...
# 309      0.023688    0.072383     -0.053346      -0.287682    -0.127833
# 310     -0.081183   -0.043319     -0.187816       0.693147    -0.200671
# 311     -0.119709   -0.050745     -0.141830      -0.693147    -0.117783
# 312     -0.067732   -0.076851     -0.165324       0.000000    -0.133531
# 313     -0.006816    0.040585     -0.081917       0.000000     0.000000
#
# [314 rows x 10 columns]

# %%
stock_returns=np.log(stock_prices.drop(['Date'],axis=1)).diff(axis = 0, periods = 1)

# %%
stock_returns.shape
# Out:
# (314, 10)

# %% [markdown]
# ### Calculating stock means

# %%
stock_means = stock_returns.mean(axis = 0)
stock_means
# Out:
# Infosys                0.002794
# Indian_Hotel           0.000266
# Mahindra_&_Mahindra   -0.001506
# Axis_Bank              0.001167
# SAIL                  -0.003463
# Shree_Cement           0.003681
# Sun_Pharma            -0.001455
# Jindal_Steel          -0.004123
# Idea_Vodafone         -0.010608
# Jet_Airways           -0.009548
# dtype: float64

# %% [markdown]
# ### Calculating stock Standard Deviation

# %%
stock_sd = stock_returns.std(axis = 0)
stock_sd
# Out:
# Infosys                0.035070
# Indian_Hotel           0.047131
# Mahindra_&_Mahindra    0.040169
# Axis_Bank              0.045828
# SAIL                   0.062188
# Shree_Cement           0.039917
# Sun_Pharma             0.045033
# Jindal_Steel           0.075108
# Idea_Vodafone          0.104315
# Jet_Airways            0.097972
# dtype: float64

# %%
plt.scatter(stock_means, stock_sd, edgecolors='r')
plt.xlabel('stock_means')
plt.ylabel('stock_sd')
plt.title('stock_means vs stock_sd')
plt.show()

# %% [markdown]
# Stock with a lower mean & higher standard deviation does not play a role in a portfolio that has competing stock with more returns & less risk.
# Thus for the data we have here, we are only left few stocks:
# - One with highest return and lowest risk &
# - One with lowest risk and highest return
