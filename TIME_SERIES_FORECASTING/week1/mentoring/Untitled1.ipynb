# %%
import pandas as pd
import numpy as np
import seaborn as sns

from matplotlib import pyplot as plt
# %matplotlib inline 
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
import os
os.chdir('E:\AIMLGLIM\TIME_SERIES_FORECASTING\week1')
os.getcwd()
# Out:
# 'E:\\AIMLGLIM\\TIME_SERIES_FORECASTING\\week1'

# %%
df = pd.read_csv("Normalized+Age.csv",parse_dates=True,squeeze=True,index_col=0)

# %%
df.head()
# Out:
# Year
# 1950-01-01    2.382149
# 1951-01-01   -0.586540
# 1952-01-01    0.421541
# 1953-01-01    0.092043
# 1954-01-01   -1.823828
# Name: Age, dtype: float64

# %%
df.plot()

# %%
decomposition = seasonal_decompose(df,model='additive')
plt.legend(["Original Time Series", "Time Series without Seasonality Component"]);
decomposition.trend.plot();
df.plot

# %%
my_list = [0,1,2,3,4,5,6]

# %%
 print(my_list[-7] )
# Out:
# 0

# %%
l = ['virat', 'kohli'] 

for element in l: 

    element.title() 

print(l)
# Out:
# ['virat', 'kohli']

# %%
x="hello"

# %%
x.title()
# Out:
# 'Hello'
