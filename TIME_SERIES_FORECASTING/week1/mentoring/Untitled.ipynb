# %%
import pandas as pd
import numpy as np
import seaborn as sns

from matplotlib import pyplot as plt

# %%
import os
os.chdir('E:\AIMLGLIM\TIME_SERIES_FORECASTING\week1\mentoring')
os.getcwd()
# Out:
# 'E:\\AIMLGLIM\\TIME_SERIES_FORECASTING\\week1\\mentoring'

# %%
df_2 = pd.read_csv("Beer Australia.csv")

# %%
df_2.head()
# Out:
#      Month  Monthly beer production
# 0  1956-01                     93.2
# 1  1956-02                     96.0
# 2  1956-03                     95.2
# 3  1956-04                     77.1
# 4  1956-05                     70.9

# %%
df_2.plot()

# %%
df_2.__len__
# Out:
# <bound method DataFrame.__len__ of        Month  Monthly beer production
# 0    1956-01                     93.2
# 1    1956-02                     96.0
# 2    1956-03                     95.2
# 3    1956-04                     77.1
# 4    1956-05                     70.9
# ..       ...                      ...
# 471  1995-04                    127.0
# 472  1995-05                    151.0
# 473  1995-06                    130.0
# 474  1995-07                    119.0
# 475  1995-08                    153.0
#
# [476 rows x 2 columns]>

# %%
type(df_2)
# Out:
# pandas.core.frame.DataFrame

# %%
date = pd.date_range(start='1/1/1956', end='9/1/1995', freq='M')

# %%
date
# Out:
# DatetimeIndex(['1956-01-31', '1956-02-29', '1956-03-31', '1956-04-30',
#                '1956-05-31', '1956-06-30', '1956-07-31', '1956-08-31',
#                '1956-09-30', '1956-10-31',
#                ...
#                '1994-11-30', '1994-12-31', '1995-01-31', '1995-02-28',
#                '1995-03-31', '1995-04-30', '1995-05-31', '1995-06-30',
#                '1995-07-31', '1995-08-31'],
#               dtype='datetime64[ns]', length=476, freq='M')

# %%
df_2
# Out:
#        Month  Monthly beer production
# 0    1956-01                     93.2
# 1    1956-02                     96.0
# 2    1956-03                     95.2
# 3    1956-04                     77.1
# 4    1956-05                     70.9
# ..       ...                      ...
# 471  1995-04                    127.0
# 472  1995-05                    151.0
# 473  1995-06                    130.0
# 474  1995-07                    119.0
# 475  1995-08                    153.0
#
# [476 rows x 2 columns]

# %%
df_2['Time_Stamp']=pd.DataFrame(date,columns=['Month'])

# %%
df_2.head()
# Out:
#      Month  Monthly beer production Time_Stamp
# 0  1956-01                     93.2 1956-01-31
# 1  1956-02                     96.0 1956-02-29
# 2  1956-03                     95.2 1956-03-31
# 3  1956-04                     77.1 1956-04-30
# 4  1956-05                     70.9 1956-05-31

# %%
plt.plot(df_2['Time_Stamp'],df_2['Monthly beer production']);
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(22,8))
sns.boxplot(df_2.Time_Stamp, df_2, ax=ax,whis=1.5)
plt.grid();
plt.xlabel('Years');
plt.ylabel('Yearly Beer Production Variation');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-a49f5bd641ce> in <module>
#       1 fig, ax = plt.subplots(figsize=(22,8))
# ----> 2 sns.boxplot(df_2.Time_Stamp[1], df_2, ax=ax,whis=1.5)
#       3 plt.grid();
#       4 plt.xlabel('Years');
#       5 plt.ylabel('Yearly Beer Production Variation');
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2233     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2234                           orient, color, palette, saturation,
# -> 2235                           width, dodge, fliersize, linewidth)
#    2236
#    2237     if ax is None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     434                  width, dodge, fliersize, linewidth):
#     435
# --> 436         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     437         self.establish_colors(color, palette, saturation)
#     438
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153
#     154             # Figure out the plotting orientation
# --> 155             orient = self.infer_orient(x, y, orient)
#     156
#     157             # Option 2a:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py in infer_orient(self, x, y, orient)
#     351                 return "h"
#     352         elif is_not_numeric(y):
# --> 353             if is_not_numeric(x):
#     354                 raise ValueError(no_numeric)
#     355             else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py in is_not_numeric(s)
#     330         def is_not_numeric(s):
#     331             try:
# --> 332                 np.asarray(s, dtype=np.float)
#     333             except ValueError:
#     334                 return True
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# TypeError: float() argument must be a string or a number, not 'Timestamp'

# %%
# Out:
# 0     1956-01-31
# 1     1956-02-29
# 2     1956-03-31
# 3     1956-04-30
# 4     1956-05-31
#          ...
# 471   1995-04-30
# 472   1995-05-31
# 473   1995-06-30
# 474   1995-07-31
# 475   1995-08-31
# Name: Time_Stamp, Length: 476, dtype: datetime64[ns]

# %%
print(pd.__version__)
# Out:
# 1.0.4

# %%
pip install pandas==1.0.3
# Out:
# Collecting pandas==1.0.3
#   Downloading pandas-1.0.3-cp37-cp37m-win_amd64.whl (8.7 MB)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\v2n\appdata\local\continuum\anaconda3\lib\site-packages (from pandas==1.0.3) (1.18.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\v2n\appdata\local\continuum\anaconda3\lib\site-packages (from pandas==1.0.3) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\v2n\appdata\local\continuum\anaconda3\lib\site-packages (from pandas==1.0.3) (2020.1)
# Requirement already satisfied: six>=1.5 in c:\users\v2n\appdata\local\continuum\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas==1.0.3) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.0.4
#     Uninstalling pandas-1.0.4:
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'c:\\users\\v2n\\appdata\\local\\continuum\\anaconda3\\lib\\site-packages\\~andas\\_libs\\algos.cp37-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#       Successfully uninstalled pandas-1.0.4

# %%
pip install pandas==1.0.3
pip install Numpy == 1.18.4
pip install Seaborn==0.10.1
pip install matplotlib ==3.2.1
pip install statsmodels == 0.11.1
# Out:
#   File "<ipython-input-92-2bd0e8ddbb14>", line 1
#     pip install pandas==1.0.3
#               ^
# SyntaxError: invalid syntax

# %%
np.__version__
# Out:
# '1.18.1'
