# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %%
auto=pd.read_csv('Automobile.csv')

# %%
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0             two  convertible          rwd           front        88.6
# 1             two  convertible          rwd           front        88.6
# 2             two    hatchback          rwd           front        94.5
# 3            four        sedan          fwd           front        99.8
# 4            four        sedan          4wd           front        99.4
#
#    ...    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
sns.distplot(auto['engine_size'])
plt.show()

# %%
sns.distplot(auto['engine_size'],kde=False,rug=True)
plt.show()

# %%
sns.jointplot(auto['engine_size'],auto['horsepower'], kind='kde')
plt.show()

# %%
sns.pairplot(auto[['engine_size','horsepower']])

# %%
auto.shape
# Out:
# (201, 26)

# %%
auto[['normalized_losses','engine_size','horsepower']].shape
# Out:
# (201, 3)

# %%
auto.dtypes
# Out:
# symboling                int64
# normalized_losses        int64
# make                    object
# fuel_type               object
# aspiration              object
# number_of_doors         object
# body_style              object
# drive_wheels            object
# engine_location         object
# wheel_base             float64
# length                 float64
# width                  float64
# height                 float64
# curb_weight              int64
# engine_type             object
# number_of_cylinders     object
# engine_size              int64
# fuel_system             object
# bore                   float64
# stroke                 float64
# compression_ratio      float64
# horsepower               int64
# peak_rpm                 int64
# city_mpg                 int64
# highway_mpg              int64
# price                    int64
# dtype: object

# %%
type(auto)
# Out:
# pandas.core.frame.DataFrame

# %%
x=pd.DataFrame(columns=["first,second"],data=[0,1])

# %%
print(x)
# Out:
#    first,second
# 0             0
# 1             1

# %%
sns.boxplot(auto['number_of_doors'],auto['horsepower'])

# %%
sns.boxplot(auto['number_of_doors'],auto['horsepower'],hue=auto['fuel_type'])

# %%
sns.countplot(auto['body_style'],hue=auto['engine_location'])

# %%
import numpy as np

# %%
a=np.linspace(1,10,9)

# %%
print a
# Out:
#   File "<ipython-input-6-9d7b17ad5387>", line 1
#     print a
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(a)?

# %%
print(a)
# Out:
# [  1.      2.125   3.25    4.375   5.5     6.625   7.75    8.875  10.   ]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %%
fifa=pd.read_csv("FIFA.csv")

# %%
fifa
# Out:
#            ID                  Name  Age          Nationality  Overall  \
# 0      158023              L. Messi   31            Argentina       94
# 1       20801     Cristiano Ronaldo   33             Portugal       94
# 2      190871             Neymar Jr   26               Brazil       92
# 3      193080                De Gea   27                Spain       91
# 4      192985          K. De Bruyne   27              Belgium       91
# 5      183277             E. Hazard   27              Belgium       91
# 6      177003             L. Modrić   32              Croatia       91
# 7      176580             L. Suárez   31              Uruguay       91
# 8      155862          Sergio Ramos   32                Spain       91
# 9      200389              J. Oblak   25             Slovenia       90
# 10     188545        R. Lewandowski   29               Poland       90
# 11     182521              T. Kroos   28              Germany       90
# ...

# %%
fifa['Value'].mean()
# Out:
# 2410695.8861976163

# %%
fifa.mean()
# Out:
# ID                          2.142983e+05
# Age                         2.512221e+01
# Overall                     6.623870e+01
# Potential                   7.130730e+01
# Value                       2.410696e+06
# Wage                        9.731312e+03
# International Reputation    1.113222e+00
# Weak Foot                   2.947299e+00
# Skill Moves                 2.361308e+00
# Jersey Number               1.954610e+01
# Contract Valid Until        2.020147e+03
# Height                      5.797367e+00
# Weight                      1.659791e+02
# Crossing                    4.973418e+01
# Finishing                   4.555091e+01
# HeadingAccuracy             5.229814e+01
# ShortPassing                5.868671e+01
# Volleys                     4.290903e+01
# Dribbling                   5.537100e+01
# Curve                       4.717082e+01
# FKAccuracy                  4.286315e+01
# LongPassing                 5.271193e+01
# BallControl                 5.836946e+01
# ...

# %%
fifa.isnull
# Out:
# <bound method NDFrame.isnull of            ID                  Name  Age          Nationality  Overall  \
# 0      158023              L. Messi   31            Argentina       94
# 1       20801     Cristiano Ronaldo   33             Portugal       94
# 2      190871             Neymar Jr   26               Brazil       92
# 3      193080                De Gea   27                Spain       91
# 4      192985          K. De Bruyne   27              Belgium       91
# 5      183277             E. Hazard   27              Belgium       91
# 6      177003             L. Modrić   32              Croatia       91
# 7      176580             L. Suárez   31              Uruguay       91
# 8      155862          Sergio Ramos   32                Spain       91
# 9      200389              J. Oblak   25             Slovenia       90
# 10     188545        R. Lewandowski   29               Poland       90
# 11     182521              T. Kroos   28              Germany       90
# ...

# %%
fifa['Contract Valid Until'].unique()
# Out:
# array([ 2021.,  2022.,  2020.,  2023.,  2019.,  2024.,  2025.,  2026.,
#         2018.,    nan])

# %%
round(fifa['Contract Valid Until'].mean())
# Out:
# 2020

# %%
fifa['International Reputation'].fillna(1).std()
# Out:
# 0.39355381169334935

# %%
fifa['Overall']
# Out:
# 0        94
# 1        94
# 2        92
# 3        91
# 4        91
# 5        91
# 6        91
# 7        91
# 8        91
# 9        90
# 10       90
# 11       90
# 12       90
# 13       90
# 14       89
# 15       89
# 16       89
# 17       89
# 18       89
# 19       89
# 20       89
# 21       89
# 22       89
# 23       89
# 24       89
# 25       88
# 26       88
# 27       88
# 28       88
# 29       88
#          ..
# 18177    48
# 18178    48
# 18179    48
# 18180    48
# 18181    48
# 18182    48
# 18183    48
# 18184    48
# 18185    48
# 18186    47
# 18187    47
# 18188    47
# 18189    47
# 18190    47
# 18191    47
# 18192    47
# 18193    47
# 18194    47
# 18195    47
# 18196    47
# 18197    47
# 18198    47
# 18199    47
# 18200    47
# 18201    47
# 18202    47
# 18203    47
# 18204    47
# 18205    47
# 18206    46
# Name: Overall, Length: 18207, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline
sns.
plt.show()

# %%
n, bins, patches = plt.hist(fifa['Overall'],10,facecolor='blue',alpha=0.5)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.scatter(fifa['Height'], fifa['Overall'], color='r')

# %%
fifa[fifa['Contract Valid Until']==2020]['Age'].mean()
# Out:
# 25.20919881305638
